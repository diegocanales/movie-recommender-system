# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ydata_profiling import ProfileReport
from movie_recommender_system import paths
import pandas as pd

# %%
movie_data_path = paths.data_raw_dir() / "tmdb_5000_movie_dataset/movies.csv"
credits_data_path = paths.data_raw_dir() / "tmdb_5000_movie_dataset/credits.csv"

# %%
df_movies = pd.read_csv(movie_data_path)
profile_movies = ProfileReport(df_movies, title="Profiling Report")
#profile_movies.to_file(paths.reports_dir() / "00_raw_movies.html")

# %%
df_credits = pd.read_csv(credits_data_path)
profile_credits = ProfileReport(df_credits, title="Profiling Report")
#profile_credits.to_file(paths.reports_dir() / "00_raw_credits.html")

# %%
df = df_movies.merge(df_credits, on="title")

df.to_csv(paths.data_processed_dir() / "dataset.csv", index=False)

# %%
list(df.columns)
# Out:
# ['budget',
#  'genres',
#  'homepage',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count',
#  'movie_id',
#  'cast',
#  'crew']

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
from movie_recommender_system.features.build_features import processing_features

# %%
df_processed = processing_features(df,
                                   cast_count=3,
                                   str_columns = ["overview", "original_title", "original_language", "release_date"],
                                   #list_dict_columns=["genres", "keywords", "production_companies", "production_countries"],
                                   list_dict_columns=["genres", "keywords", "production_companies"],
                                   #crew_jobs_list=["Director", "Producer", "Screenplay", "Writer", "Story"],
                                   crew_jobs_list=["Director"])

# %%
df_processed
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4779      2292                                    Clerks
# 4787    255266                                 Dry Spell
# 4797    157185                               Tin Can Man
# 4802     14337                                    Primer
# 4807    126186                          Shanghai Calling
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# ...

# %%
from movie_recommender_system.models.model import MovieRecommender

# %%
recommender = MovieRecommender()
recommender.fit(df_processed)
# Out:
# MovieRecommender()

# %%
print(recommender.predict('The Amazing Spider-Man 2'))
# Out:
# ['Faster', 'Speed Racer', 'Perrier’s Bounty', 'The Peanuts Movie', "Should've Been Romeo"]
